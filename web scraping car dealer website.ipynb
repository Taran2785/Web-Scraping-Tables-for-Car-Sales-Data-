# %% [markdown]
# # Web Scraping Car delaer website

# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# HTTP Request

# %% [markdown]
# store website in variable

# %%
website = "https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=tesla&models%5B%5D=&list_price_max=&maximum_distance=all&zip="

# %% [markdown]
# Get Request

# %%
response = requests.get(website)

# %% [markdown]
# Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# Results

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %% [markdown]
# Target necessary data

# %%
# Name
# Dealer Name
# Rating
# Rating Count
# Price

# %% [markdown]
# Name

# %%
results[0].find('h2').get_text()
# Out:
# '2021 Tesla Model X Long Range'

# %% [markdown]
# Dealer Name

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip
# Out:
# <function str.strip(chars=None, /)>

# %% [markdown]
# Rating

# %%
results[0].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '3.9'

# %% [markdown]
# Review Count

# %%
results[0].find('span', {'class':'sds-rating__link'}).get_text()
# Out:
# '(87 reviews)'

# %% [markdown]
# Price

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$80,887'

# %% [markdown]
# # Put everything together inside a For-Loop

# %%
name = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %% [markdown]
# # Create Pandas Dataframe

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                       Name  \
# 0            2021 Tesla Model X Long Range
# 1           2022 Tesla Model Y Performance
# 2                   2018 Tesla Model S 75D
# 3            2022 Tesla Model 3 Long Range
# 4                  2013 Tesla Model S Base
# 5            2020 Tesla Model Y Long Range
# 6                 2021 Tesla Model S Plaid
# 7   2020 Tesla Model 3 Standard Range Plus
# 8                 2017 Tesla Model S P100D
# 9                    2017 Tesla Model S 75
# 10                2021 Tesla Model S Plaid
# 11                  2016 Tesla Model S 90D
# 12           2019 Tesla Model X Long Range
# 13          2023 Tesla Model Y Performance
# 14            2022 Tesla Model X LONG RANG
# 15                 2022 Tesla Model S Base
# 16           2021 Tesla Model 3 Long Range
# 17           2020 Tesla Model 3 Long Range
# 18          2021 Tesla Model 3 Performance
# 19           2018 Tesla Model 3 Long Range
# 20      2020 Tesla Model X Long Range Plus
#
#                                           Dealer Name Rating     Review Count  \
# 0                          Volkswagen of Palm Springs    3.9     (87 reviews)
# 1                                 Fox Ford of Chicago    4.7  (1,733 reviews)
# 2                                     Naples INFINITI    4.9    (747 reviews)
# 3                      Cowboy Chrysler Dodge Jeep Ram    4.4     (35 reviews)
# 4                                 Inside Car Guys LLC    n/a       (1 review)
# 5   CarMax Tallahassee - Offering Express Pickup a...    n/a      (3 reviews)
# 6   CarMax Boise (Meridian) - Offering Express Pic...    n/a      (4 reviews)
# 7                                Capitol Chevrolet AL    4.8    (248 reviews)
# 8                                                 n/a    n/a              n/a
# 9                                        Capital Ford    4.3  (1,671 reviews)
# 10                                      BMW of Eugene    4.5    (102 reviews)
# 11                                  Auto Valley Group    n/a      (4 reviews)
# 12                JTs Dodgeland of Columbia Dodge RAM    4.2    (861 reviews)
# 13                                Westcott Automotive    n/a     (64 reviews)
# 14                                Foreign Cars Italia    4.9  (1,313 reviews)
# 15                                     Audi Flatirons    4.8  (1,159 reviews)
# 16                         McCarthy Toyota of Sedalia    3.9    (110 reviews)
# 17                             Boulevard Ford Lincoln    n/a    (258 reviews)
# 18                                   Corwin Ford Reno    4.6    (444 reviews)
# 19                           Ryan Friedman Motor Cars    4.9     (22 reviews)
# 20                                          Cars Land    4.2      (6 reviews)
#
#        Price
# 0    $80,887
# 1    $56,726
# 2    $42,999
# 3    $47,529
# 4    $27,499
# 5    $46,998
# 6    $94,998
# 7    $30,996
# 8    $55,498
# 9    $37,840
# 10   $96,750
# 11   $41,990
# 12   $55,990
# 13   $59,770
# 14  $109,990
# 15   $82,635
# 16   $41,739
# 17   $36,800
# 18   $46,989
# 19   $34,995
# 20   $69,500

# %% [markdown]
# Data Cleaning

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                       Name  \
# 0            2021 Tesla Model X Long Range
# 1           2022 Tesla Model Y Performance
# 2                   2018 Tesla Model S 75D
# 3            2022 Tesla Model 3 Long Range
# 4                  2013 Tesla Model S Base
# 5            2020 Tesla Model Y Long Range
# 6                 2021 Tesla Model S Plaid
# 7   2020 Tesla Model 3 Standard Range Plus
# 8                 2017 Tesla Model S P100D
# 9                    2017 Tesla Model S 75
# 10                2021 Tesla Model S Plaid
# 11                  2016 Tesla Model S 90D
# 12           2019 Tesla Model X Long Range
# 13          2023 Tesla Model Y Performance
# 14            2022 Tesla Model X LONG RANG
# 15                 2022 Tesla Model S Base
# 16           2021 Tesla Model 3 Long Range
# 17           2020 Tesla Model 3 Long Range
# 18          2021 Tesla Model 3 Performance
# 19           2018 Tesla Model 3 Long Range
# 20      2020 Tesla Model X Long Range Plus
#
#                                           Dealer Name Rating Review Count  \
# 0                          Volkswagen of Palm Springs    3.9          87
# 1                                 Fox Ford of Chicago    4.7       1,733
# 2                                     Naples INFINITI    4.9         747
# 3                      Cowboy Chrysler Dodge Jeep Ram    4.4          35
# 4                                 Inside Car Guys LLC    n/a           1
# 5   CarMax Tallahassee - Offering Express Pickup a...    n/a           3
# 6   CarMax Boise (Meridian) - Offering Express Pic...    n/a           4
# 7                                Capitol Chevrolet AL    4.8         248
# 8                                                 n/a    n/a          n/a
# 9                                        Capital Ford    4.3       1,671
# 10                                      BMW of Eugene    4.5         102
# 11                                  Auto Valley Group    n/a           4
# 12                JTs Dodgeland of Columbia Dodge RAM    4.2         861
# 13                                Westcott Automotive    n/a          64
# 14                                Foreign Cars Italia    4.9       1,313
# 15                                     Audi Flatirons    4.8       1,159
# 16                         McCarthy Toyota of Sedalia    3.9         110
# 17                             Boulevard Ford Lincoln    n/a         258
# 18                                   Corwin Ford Reno    4.6         444
# 19                           Ryan Friedman Motor Cars    4.9          22
# 20                                          Cars Land    4.2           6
#
#        Price
# 0    $80,887
# 1    $56,726
# 2    $42,999
# 3    $47,529
# 4    $27,499
# 5    $46,998
# 6    $94,998
# 7    $30,996
# 8    $55,498
# 9    $37,840
# 10   $96,750
# 11   $41,990
# 12   $55,990
# 13   $59,770
# 14  $109,990
# 15   $82,635
# 16   $41,739
# 17   $36,800
# 18   $46,989
# 19   $34,995
# 20   $69,500

# %% [markdown]
# Output in Excel

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %% [markdown]
# Pagination

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):
    
    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip=' 
    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    # loop through results
    for result in results:
    
        # name
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price 
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0     2021 Mercedes-Benz GLA 250 Base 4MATIC  32,227 mi.
# 1    2021 Mercedes-Benz E-Class E 450 4MATIC  10,927 mi.
# 2     2020 Mercedes-Benz GLE 350 Base 4MATIC  46,567 mi.
# 3    2019 Mercedes-Benz AMG S 63 Base 4MATIC  45,954 mi.
# 4           2016 Mercedes-Benz E-Class E 400  34,794 mi.
# ..                                       ...         ...
# 197          2020 Mercedes-Benz SLC 300 Base  27,606 mi.
# 198   2018 Mercedes-Benz GLS 450 Base 4MATIC  39,498 mi.
# 199         2021 Mercedes-Benz AMG G 63 Base  35,027 mi.
# 200  2021 Mercedes-Benz AMG E 53 Base 4MATIC   6,405 mi.
# 201            2017 Mercedes-Benz AMG C 63 S  28,205 mi.
#
#                                            Dealer Name Rating  \
# 0                         Mercedes-Benz of Centerville    4.7
# 1                             Mercedes-Benz of Raleigh    5.0
# 2                        Napleton Autowerks Loves Park    4.9
# 3                           Mercedes-Benz of Nashville    4.4
# 4                         Mercedes-Benz of Baton Rouge    5.0
# ..                                                 ...    ...
# 197                                     RBM of Atlanta    4.2
# 198                            Mercedes-Benz of Delray    4.5
# 199                             Mercedes-Benz Of Tampa    4.1
# 200  Mercedes-Benz of San Francisco / Smart Center ...    n/a
# 201                Mercedes-Benz of Northwest Arkansas    n/a
#
#         Review Count     Price
# 0       (35 reviews)   $35,903
# 1    (1,700 reviews)   $67,985
# 2      (839 reviews)   $46,999
# 3      (894 reviews)   $88,927
# 4      (844 reviews)   $29,952
# ..               ...       ...
# 197  (1,025 reviews)   $45,843
# 198  (1,634 reviews)   $44,884
# 199  (3,507 reviews)  $203,562
# 200     (62 reviews)   $76,988
# 201     (45 reviews)   $56,068
#
# [202 rows x 6 columns]

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0     2021 Mercedes-Benz GLA 250 Base 4MATIC  32,227 mi.
# 1    2021 Mercedes-Benz E-Class E 450 4MATIC  10,927 mi.
# 2     2020 Mercedes-Benz GLE 350 Base 4MATIC  46,567 mi.
# 3    2019 Mercedes-Benz AMG S 63 Base 4MATIC  45,954 mi.
# 4           2016 Mercedes-Benz E-Class E 400  34,794 mi.
# ..                                       ...         ...
# 197          2020 Mercedes-Benz SLC 300 Base  27,606 mi.
# 198   2018 Mercedes-Benz GLS 450 Base 4MATIC  39,498 mi.
# 199         2021 Mercedes-Benz AMG G 63 Base  35,027 mi.
# 200  2021 Mercedes-Benz AMG E 53 Base 4MATIC   6,405 mi.
# 201            2017 Mercedes-Benz AMG C 63 S  28,205 mi.
#
#                                            Dealer Name Rating Review Count  \
# 0                         Mercedes-Benz of Centerville    4.7          35
# 1                             Mercedes-Benz of Raleigh    5.0       1,700
# 2                        Napleton Autowerks Loves Park    4.9         839
# 3                           Mercedes-Benz of Nashville    4.4         894
# 4                         Mercedes-Benz of Baton Rouge    5.0         844
# ..                                                 ...    ...          ...
# 197                                     RBM of Atlanta    4.2       1,025
# 198                            Mercedes-Benz of Delray    4.5       1,634
# 199                             Mercedes-Benz Of Tampa    4.1       3,507
# 200  Mercedes-Benz of San Francisco / Smart Center ...    n/a          62
# 201                Mercedes-Benz of Northwest Arkansas    n/a          45
#
#         Price
# 0     $35,903
# 1     $67,985
# 2     $46,999
# 3     $88,927
# 4     $29,952
# ..        ...
# 197   $45,843
# 198   $44,884
# 199  $203,562
# 200   $76,988
# 201   $56,068
#
# [202 rows x 6 columns]

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)
